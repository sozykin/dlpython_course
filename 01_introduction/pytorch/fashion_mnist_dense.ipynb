# %% [markdown]
# # Библиотека PyTorch
#
# Обучаем нейронную сеть распознавать модели одежды из набора данных [FashionMNIST](https://github.com/zalandoresearch/fashion-mnist).

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline

# %% [markdown]
# Загружаем набор данных [FashionMNIST](https://github.com/zalandoresearch/fashion-mnist).

# %%
# Загружаем набор данных для обучения
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor(),
)

# Загружаем набор данных для тестирования
test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor(),
)
# Out:
# 100%|██████████| 26.4M/26.4M [00:01<00:00, 14.4MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 211kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.94MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 9.81MB/s]

# %%
training_data[0]
# Out:
# (tensor([[[0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.0000, 0.0510,
#            0.2863, 0.0000, 0.0000, 0.0039, 0.0157, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0118, 0.0000, 0.1412, 0.5333,
#            0.4980, 0.2431, 0.2118, 0.0000, 0.0000, 0.0000, 0.0039, 0.0118,
#            0.0157, 0.0000, 0.0000, 0.0118],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0235, 0.0000, 0.4000, 0.8000,
#            0.6902, 0.5255, 0.5647, 0.4824, 0.0902, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0471, 0.0392, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.6078, 0.9255,
#            0.8118, 0.6980, 0.4196, 0.6118, 0.6314, 0.4275, 0.2510, 0.0902,
#            0.3020, 0.5098, 0.2824, 0.0588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0039, 0.0000, 0.2706, 0.8118, 0.8745,
#            0.8549, 0.8471, 0.8471, 0.6392, 0.4980, 0.4745, 0.4784, 0.5725,
#            0.5529, 0.3451, 0.6745, 0.2588],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0039, 0.0039, 0.0000, 0.7843, 0.9098, 0.9098,
#            0.9137, 0.8980, 0.8745, 0.8745, 0.8431, 0.8353, 0.6431, 0.4980,
#            0.4824, 0.7686, 0.8980, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7176, 0.8824, 0.8471,
#            0.8745, 0.8941, 0.9216, 0.8902, 0.8784, 0.8706, 0.8784, 0.8667,
#            0.8745, 0.9608, 0.6784, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.7569, 0.8941, 0.8549,
#            0.8353, 0.7765, 0.7059, 0.8314, 0.8235, 0.8275, 0.8353, 0.8745,
#            0.8627, 0.9529, 0.7922, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0039, 0.0118, 0.0000, 0.0471, 0.8588, 0.8627, 0.8314,
#            0.8549, 0.7529, 0.6627, 0.8902, 0.8157, 0.8549, 0.8784, 0.8314,
#            0.8863, 0.7725, 0.8196, 0.2039],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0235, 0.0000, 0.3882, 0.9569, 0.8706, 0.8627,
#            0.8549, 0.7961, 0.7765, 0.8667, 0.8431, 0.8353, 0.8706, 0.8627,
#            0.9608, 0.4667, 0.6549, 0.2196],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0157, 0.0000, 0.0000, 0.2157, 0.9255, 0.8941, 0.9020,
#            0.8941, 0.9412, 0.9098, 0.8353, 0.8549, 0.8745, 0.9176, 0.8510,
#            0.8510, 0.8196, 0.3608, 0.0000],
#           [0.0000, 0.0000, 0.0039, 0.0157, 0.0235, 0.0275, 0.0078, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.9294, 0.8863, 0.8510, 0.8745,
#            0.8706, 0.8588, 0.8706, 0.8667, 0.8471, 0.8745, 0.8980, 0.8431,
#            0.8549, 1.0000, 0.3020, 0.0000],
#           [0.0000, 0.0118, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.2431, 0.5686, 0.8000, 0.8941, 0.8118, 0.8353, 0.8667,
#            0.8549, 0.8157, 0.8275, 0.8549, 0.8784, 0.8745, 0.8588, 0.8431,
#            0.8784, 0.9569, 0.6235, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0706, 0.1725, 0.3216, 0.4196,
#            0.7412, 0.8941, 0.8627, 0.8706, 0.8510, 0.8863, 0.7843, 0.8039,
#            0.8275, 0.9020, 0.8784, 0.9176, 0.6902, 0.7373, 0.9804, 0.9725,
#            0.9137, 0.9333, 0.8431, 0.0000],
#           [0.0000, 0.2235, 0.7333, 0.8157, 0.8784, 0.8667, 0.8784, 0.8157,
#            0.8000, 0.8392, 0.8157, 0.8196, 0.7843, 0.6235, 0.9608, 0.7569,
#            0.8078, 0.8745, 1.0000, 1.0000, 0.8667, 0.9176, 0.8667, 0.8275,
#            0.8627, 0.9098, 0.9647, 0.0000],
#           [0.0118, 0.7922, 0.8941, 0.8784, 0.8667, 0.8275, 0.8275, 0.8392,
#            0.8039, 0.8039, 0.8039, 0.8627, 0.9412, 0.3137, 0.5882, 1.0000,
#            0.8980, 0.8667, 0.7373, 0.6039, 0.7490, 0.8235, 0.8000, 0.8196,
#            0.8706, 0.8941, 0.8824, 0.0000],
#           [0.3843, 0.9137, 0.7765, 0.8235, 0.8706, 0.8980, 0.8980, 0.9176,
#            0.9765, 0.8627, 0.7608, 0.8431, 0.8510, 0.9451, 0.2549, 0.2863,
#            0.4157, 0.4588, 0.6588, 0.8588, 0.8667, 0.8431, 0.8510, 0.8745,
#            0.8745, 0.8784, 0.8980, 0.1137],
#           [0.2941, 0.8000, 0.8314, 0.8000, 0.7569, 0.8039, 0.8275, 0.8824,
#            0.8471, 0.7255, 0.7725, 0.8078, 0.7765, 0.8353, 0.9412, 0.7647,
#            0.8902, 0.9608, 0.9373, 0.8745, 0.8549, 0.8314, 0.8196, 0.8706,
#            0.8627, 0.8667, 0.9020, 0.2627],
#           [0.1882, 0.7961, 0.7176, 0.7608, 0.8353, 0.7725, 0.7255, 0.7451,
#            0.7608, 0.7529, 0.7922, 0.8392, 0.8588, 0.8667, 0.8627, 0.9255,
#            0.8824, 0.8471, 0.7804, 0.8078, 0.7294, 0.7098, 0.6941, 0.6745,
#            0.7098, 0.8039, 0.8078, 0.4510],
#           [0.0000, 0.4784, 0.8588, 0.7569, 0.7020, 0.6706, 0.7176, 0.7686,
#            0.8000, 0.8235, 0.8353, 0.8118, 0.8275, 0.8235, 0.7843, 0.7686,
#            0.7608, 0.7490, 0.7647, 0.7490, 0.7765, 0.7529, 0.6902, 0.6118,
#            0.6549, 0.6941, 0.8235, 0.3608],
#           [0.0000, 0.0000, 0.2902, 0.7412, 0.8314, 0.7490, 0.6863, 0.6745,
#            0.6863, 0.7098, 0.7255, 0.7373, 0.7412, 0.7373, 0.7569, 0.7765,
#            0.8000, 0.8196, 0.8235, 0.8235, 0.8275, 0.7373, 0.7373, 0.7608,
#            0.7529, 0.8471, 0.6667, 0.0000],
#           [0.0078, 0.0000, 0.0000, 0.0000, 0.2588, 0.7843, 0.8706, 0.9294,
#            0.9373, 0.9490, 0.9647, 0.9529, 0.9569, 0.8667, 0.8627, 0.7569,
#            0.7490, 0.7020, 0.7137, 0.7137, 0.7098, 0.6902, 0.6510, 0.6588,
#            0.3882, 0.2275, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.1569,
#            0.2392, 0.1725, 0.2824, 0.1608, 0.1373, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000],
#           [0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000, 0.0000,
#            0.0000, 0.0000, 0.0000, 0.0000]]]),
#  9)

# %% [markdown]
# Создаем ``DataLoader`` - загрузчик набора данных.

# %%
# Размер мини-выборки
batch_size = 64

# Создаем загрузчики данных
train_dataloader = DataLoader(training_data, batch_size=batch_size)
test_dataloader = DataLoader(test_data, batch_size=batch_size)

for X, y in test_dataloader:
    print(f"Размерность X [N, C, H, W]: {X.shape}")
    print(f"Размерность y: {y.shape} {y.dtype}")
    break
# Out:
# Размерность X [N, C, H, W]: torch.Size([64, 1, 28, 28])
# Размерность y: torch.Size([64]) torch.int64

# %% [markdown]
# Названия классов

# %%
classes_names = ['Футболка', 'Брюки', 'Свитер', 'Платье', 'Плащ',
                 'Сандали', 'Рубашка', 'Кроссовки', 'Сумка', 'Ботинки']

# %% [markdown]
# Просматриваем примеры изображений

# %%
nsamples=10

imgs, labels = next(iter(train_dataloader))

fig=plt.figure(figsize=(12,5),facecolor='w')
for i in range(nsamples):
    ax = plt.subplot(1,nsamples, i+1)
    plt.imshow(imgs[i, 0, :, :], vmin=0, vmax=1.0, cmap=cm.gray)
    ax.set_title(classes_names[labels[i]], fontsize=10)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ## Создаем модель

# %% [markdown]
# Задаем устройство для работы модели
#
#
# *   cpu - центральный процессор
# *   cude - графический ускоритель NVIDIA
# *   mps - графический ускоритель MAC

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)

# %%
device
# Out:
# 'cuda'

# %%
# !nvidia-smi
# Out:
# Thu May  7 04:04:04 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Описываем класс для модели

# %%
class NeuralNetwork(nn.Module):

    def __init__(self):
        super().__init__()
        # Слой преобразует двумерное изображение 28х28 в плоский вектор
        # размером 1х784
        self.flatten = nn.Flatten()
        # Контейней, содержащий слои, соединенные последовательно
        self.linear_relu_stack = nn.Sequential(
            # Полносвязный слой, 784 входа, 800 выходов
            nn.Linear(784, 800),
            # Полулинейная функция активации
            nn.ReLU(),
            # Полносвязный слой, 800 входов, 10 выходов (по количеству классов)
            nn.Linear(800, 10),
        )

    # Функция прямого прохода
    def forward(self, x):
        x = self.flatten(x)
        x = self.linear_relu_stack(x)
        return x

# %% [markdown]
# Создаем модель на основе описанного класса

# %%
model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=800, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=800, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# --------------

# %% [markdown]
# ## Обучаем модель
#
# Задаем функцию ошибки - категориальная перекрестная энтропия

# %%
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# Задаем оптимизатор

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# Определяем функцию для обучения нейронной сети

# %%
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    # Включаем режим обучения
    model.train()
    # В цикле получаем все мини-выборки
    # X - изображение
    # y - номер класса
    for batch, (X, y) in enumerate(dataloader):
        # Передаем данные на устройство
        X, y = X.to(device), y.to(device)
        # Обнуляем значения градиента
        optimizer.zero_grad()

        # Расчитываем данные на выходе из нейронной сети
        pred = model(X)

        # Расчитываем значение ошибки
        loss = loss_fn(pred, y)

        # Обратное распространение ошиби
        loss.backward()

        # Выполняем шаг обучения (изменение весов)
        optimizer.step()

        # Печатаем прогресс каждые 100 мини-выборок
        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"Ошибка: {loss:>7f}  [{current:>5d}/{size:>5d}]")

# %% [markdown]
# Определяем функцию для проверки качества работы нейронной сети на тестовом наборе данных

# %%
def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    # Включаем режим оценки качества модели
    model.eval()
    # Начальные значения
    test_loss, correct = 0, 0
    # Для оценки качества работы не нужно рассчитывать градиент
    with torch.no_grad():
        # В цикле проходим по мини-выборкам из тестового набора данных
        for X, y in dataloader:
            # Передаем данные на устройство
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Качество на тестовом наборе данных: \n Доля правильных ответов: {(100*correct):>0.1f}%, средняя ошибка: {test_loss:>8f} \n")

# %% [markdown]
# Обучаем модель в течение 10 эпох

# %%
epochs = 10
for t in range(epochs):
    print(f"Эпоха {t+1}\n-------------------------------")
    # Обучение модели
    train(train_dataloader, model, loss_fn, optimizer)
    # Оценка качества работы на тестовом объеме данных
    test(test_dataloader, model, loss_fn)
print("Обучение завершено!")
# Out:
# Эпоха 1
# -------------------------------
# Ошибка: 2.303080  [   64/60000]
# Ошибка: 0.608388  [ 6464/60000]
# Ошибка: 0.384593  [12864/60000]
# Ошибка: 0.539001  [19264/60000]
# Ошибка: 0.439670  [25664/60000]
# Ошибка: 0.435302  [32064/60000]
# Ошибка: 0.394587  [38464/60000]
# Ошибка: 0.569916  [44864/60000]
# Ошибка: 0.478186  [51264/60000]
# Ошибка: 0.502890  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 84.9%, средняя ошибка: 0.422761
#
# Эпоха 2
# -------------------------------
# Ошибка: 0.265922  [   64/60000]
# Ошибка: 0.337444  [ 6464/60000]
# Ошибка: 0.286175  [12864/60000]
# Ошибка: 0.402018  [19264/60000]
# Ошибка: 0.397173  [25664/60000]
# Ошибка: 0.383771  [32064/60000]
# Ошибка: 0.352447  [38464/60000]
# Ошибка: 0.518672  [44864/60000]
# Ошибка: 0.376844  [51264/60000]
# Ошибка: 0.452922  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 85.5%, средняя ошибка: 0.395604
#
# Эпоха 3
# -------------------------------
# Ошибка: 0.221717  [   64/60000]
# Ошибка: 0.292200  [ 6464/60000]
# Ошибка: 0.230704  [12864/60000]
# Ошибка: 0.326053  [19264/60000]
# Ошибка: 0.393868  [25664/60000]
# Ошибка: 0.362201  [32064/60000]
# Ошибка: 0.311112  [38464/60000]
# Ошибка: 0.450372  [44864/60000]
# Ошибка: 0.326041  [51264/60000]
# Ошибка: 0.416440  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 86.8%, средняя ошибка: 0.364514
#
# Эпоха 4
# -------------------------------
# Ошибка: 0.207880  [   64/60000]
# Ошибка: 0.269495  [ 6464/60000]
# Ошибка: 0.222559  [12864/60000]
# Ошибка: 0.292410  [19264/60000]
# Ошибка: 0.385116  [25664/60000]
# Ошибка: 0.323392  [32064/60000]
# Ошибка: 0.280016  [38464/60000]
# Ошибка: 0.445089  [44864/60000]
# Ошибка: 0.305490  [51264/60000]
# Ошибка: 0.377995  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 86.0%, средняя ошибка: 0.387745
#
# Эпоха 5
# -------------------------------
# Ошибка: 0.237688  [   64/60000]
# Ошибка: 0.261636  [ 6464/60000]
# Ошибка: 0.218829  [12864/60000]
# Ошибка: 0.273171  [19264/60000]
# Ошибка: 0.423128  [25664/60000]
# Ошибка: 0.312213  [32064/60000]
# Ошибка: 0.254844  [38464/60000]
# Ошибка: 0.364214  [44864/60000]
# Ошибка: 0.279272  [51264/60000]
# Ошибка: 0.376735  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 86.7%, средняя ошибка: 0.367598
#
# Эпоха 6
# -------------------------------
# Ошибка: 0.216430  [   64/60000]
# Ошибка: 0.240823  [ 6464/60000]
# Ошибка: 0.221905  [12864/60000]
# Ошибка: 0.256813  [19264/60000]
# Ошибка: 0.438732  [25664/60000]
# Ошибка: 0.303480  [32064/60000]
# Ошибка: 0.255962  [38464/60000]
# Ошибка: 0.349687  [44864/60000]
# Ошибка: 0.282724  [51264/60000]
# Ошибка: 0.348296  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 87.5%, средняя ошибка: 0.344134
#
# Эпоха 7
# -------------------------------
# Ошибка: 0.210534  [   64/60000]
# Ошибка: 0.218904  [ 6464/60000]
# Ошибка: 0.201854  [12864/60000]
# Ошибка: 0.249600  [19264/60000]
# Ошибка: 0.344574  [25664/60000]
# Ошибка: 0.282165  [32064/60000]
# Ошибка: 0.236306  [38464/60000]
# Ошибка: 0.311100  [44864/60000]
# Ошибка: 0.251756  [51264/60000]
# Ошибка: 0.318486  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 87.5%, средняя ошибка: 0.350993
#
# Эпоха 8
# -------------------------------
# Ошибка: 0.182193  [   64/60000]
# Ошибка: 0.191777  [ 6464/60000]
# Ошибка: 0.208682  [12864/60000]
# Ошибка: 0.245017  [19264/60000]
# Ошибка: 0.377500  [25664/60000]
# Ошибка: 0.259055  [32064/60000]
# Ошибка: 0.229788  [38464/60000]
# Ошибка: 0.338994  [44864/60000]
# Ошибка: 0.244508  [51264/60000]
# Ошибка: 0.268715  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 87.9%, средняя ошибка: 0.343745
#
# Эпоха 9
# -------------------------------
# Ошибка: 0.174532  [   64/60000]
# Ошибка: 0.219742  [ 6464/60000]
# Ошибка: 0.221034  [12864/60000]
# Ошибка: 0.228686  [19264/60000]
# Ошибка: 0.398991  [25664/60000]
# Ошибка: 0.273965  [32064/60000]
# Ошибка: 0.227830  [38464/60000]
# Ошибка: 0.311201  [44864/60000]
# Ошибка: 0.247882  [51264/60000]
# Ошибка: 0.263385  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 87.7%, средняя ошибка: 0.350683
#
# Эпоха 10
# -------------------------------
# Ошибка: 0.172703  [   64/60000]
# Ошибка: 0.197228  [ 6464/60000]
# Ошибка: 0.205166  [12864/60000]
# Ошибка: 0.212491  [19264/60000]
# Ошибка: 0.411107  [25664/60000]
# Ошибка: 0.251838  [32064/60000]
# Ошибка: 0.247504  [38464/60000]
# Ошибка: 0.275444  [44864/60000]
# Ошибка: 0.207645  [51264/60000]
# Ошибка: 0.231386  [57664/60000]
# Качество на тестовом наборе данных:
#  Доля правильных ответов: 87.9%, средняя ошибка: 0.343713
#
# Обучение завершено!

# %% [markdown]
# ## Сохранение обученной модели

# %% [markdown]
# Параметры модели

# %%
model.state_dict()
# Out:
# OrderedDict([('linear_relu_stack.0.weight',
#               tensor([[ 1.8587e-01, -5.3892e-02,  3.5400e-02,  ...,  1.3794e-01,
#                         2.8179e-01,  1.9395e-01],
#                       [-4.0102e-02, -4.7812e-03, -1.9485e-04,  ..., -8.0727e-02,
#                        -3.0326e-02, -5.3217e-05],
#                       [ 9.4070e-02,  6.6387e-02,  4.9684e-02,  ..., -5.0131e-02,
#                        -8.7173e-03,  1.1850e-01],
#                       ...,
#                       [ 5.7040e-03, -2.7605e-01, -1.4440e-01,  ..., -1.3327e-01,
#                        -1.3016e-01,  2.1347e-01],
#                       [ 1.8079e-03,  2.2840e-02,  1.8611e-02,  ..., -5.2365e-02,
#                         8.1610e-04,  4.2248e-02],
#                       [-1.6099e-01,  5.4384e-02,  8.3893e-02,  ..., -6.4162e-03,
#                        -1.9588e-01, -2.6031e-02]], device='cuda:0')),
#              ('linear_relu_stack.0.bias',
#               tensor([ 5.2279e-02,  8.4115e-02,  4.0773e-01,  1.5336e-01, -1.3596e-02,
#                       -1.5011e-01,  2.4878e-01,  5.8569e-02,  2.4250e-01, -1.2023e-01,
#                       -1.1616e-01,  1.8582e-01, -2.8773e-02,  3.3109e-01,  3.1516e-01,
#                        2.7904e-02,  2.1692e-01,  2.2404e-01,  3.3659e-01, -2.1698e-01,
#                       -1.0861e-02,  1.3136e-01,  3.7417e-01,  3.2326e-01, -3.0170e-02,
#                        2.0422e-01,  6.2764e-02,  2.5554e-01,  5.3878e-01, -8.6083e-02,
#                        1.7472e-01, -1.5098e-01, -2.7206e-02, -1.5294e-01,  2.8578e-01,
#                        5.6572e-02, -8.1828e-02,  2.9820e-01, -3.9367e-02,  1.9353e-02,
#                        4.2334e-02,  1.5366e-02,  1.8342e-01,  3.9361e-01, -2.9817e-02,
#                        7.7426e-02,  4.3413e-01,  3.0083e-01,  1.6013e-01,  2.6910e-03,
#                        2.2115e-01, -5.2600e-03,  1.9319e-01,  1.0805e-01, -2.2398e-01,
#                        1.4641e-01,  1.0226e-01,  3.6967e-03,  2.1236e-03,  5.2945e-02,
#                        2.4823e-01,  7.6270e-02,  1.8021e-02,  5.6829e-02,  7.9823e-02,
#                       -1.2319e-01, -3.3899e-02,  1.9569e-01,  2.3228e-01,  1.4432e-01,
#                        3.9463e-01,  2.5337e-01,  2.0267e-01,  6.6878e-02,  3.1712e-01,
#                        8.8245e-02,  2.8223e-01,  3.3942e-01,  2.8025e-02,  2.5088e-01,
#                        2.8654e-02,  1.3619e-01,  1.9744e-01,  3.8098e-01, -2.3983e-01,
#                       -1.3723e-01,  2.8938e-01,  5.6389e-02,  1.5705e-01,  3.1365e-01,
#                        1.2349e-01,  5.8221e-02,  2.3939e-01,  1.4023e-01,  3.6377e-01,
#                        2.0216e-01, -9.5040e-02,  9.0185e-02,  2.8977e-01,  2.9391e-01,
#                       -3.4010e-02,  1.3173e-01,  3.0057e-02,  2.9313e-01,  5.5103e-03,
#                       -5.7485e-02,  8.0862e-02,  2.5897e-01, -3.2651e-01,  2.6084e-01,
#                        1.4592e-02,  2.1329e-01,  2.6858e-01,  1.6147e-01,  8.5245e-02,
#                        3.0713e-01,  2.9719e-01, -2.5514e-03, -4.5457e-02,  1.9263e-01,
#                        4.6216e-02, -1.3458e-02,  1.9271e-01, -1.9040e-01,  1.2930e-01,
#                        1.7393e-01,  1.4076e-01,  1.7567e-01, -1.1882e-02,  6.4675e-02,
#                       -2.7482e-02,  1.2179e-01, -1.8423e-01,  2.9610e-02, -2.7710e-01,
#                       -4.6910e-03,  2.6034e-02,  1.0542e-02,  2.4897e-01,  4.0245e-01,
#                        2.0861e-01,  2.1714e-02,  8.2135e-03,  3.7928e-01, -2.3480e-01,
#                       -2.5939e-02,  3.6249e-01,  1.0969e-02,  2.3866e-01,  3.7372e-01,
#                       -1.3771e-02,  2.3081e-01,  1.3395e-01,  2.9733e-01, -2.9215e-01,
#                        6.2550e-03,  3.0114e-01,  3.8391e-01,  1.0249e-01, -1.8791e-02,
#                        1.8177e-01,  1.9907e-01,  1.5235e-02,  3.5308e-02,  5.2137e-02,
#                        1.7691e-01,  2.7341e-01,  2.1160e-01,  1.9526e-02,  6.1796e-02,
#                        3.4271e-01,  3.4007e-01,  2.0797e-02, -1.0038e-02,  2.6890e-01,
#                        1.7825e-02,  2.5257e-01, -9.9277e-03,  1.2444e-01, -1.8688e-01,
#                        3.8006e-01,  2.8646e-01, -7.4163e-02,  1.9273e-01, -3.6957e-02,
#                       -8.0160e-02, -3.0156e-02,  2.7200e-01,  3.4096e-01,  2.3859e-02,
#                        3.3457e-01,  4.1651e-01,  2.7403e-02,  2.8385e-03, -2.0574e-01,
#                       -1.1054e-02,  3.8006e-02, -3.6107e-02,  2.0021e-01,  2.1276e-01,
#                        1.7530e-02,  3.7867e-01,  2.5296e-02,  1.3439e-01,  3.5199e-02,
#                        2.8159e-01,  1.5314e-04,  3.1642e-02,  3.0041e-01,  3.9365e-01,
#                       -7.6646e-02,  2.9755e-01,  8.4683e-04,  2.4104e-01,  1.5800e-01,
#                        2.3936e-01,  4.3529e-01, -5.8235e-02,  1.8406e-01,  3.6656e-01,
#                        1.3186e-01, -4.1483e-02,  8.7890e-02,  3.4430e-02,  6.0603e-02,
#                        6.7684e-03, -1.7003e-02,  1.7800e-01, -2.6467e-02, -2.8918e-02,
#                        1.3576e-01, -1.1781e-01,  3.5911e-01,  1.2761e-01, -5.8731e-03,
#                       -3.1552e-02,  1.9847e-01, -8.3494e-03,  1.4597e-01, -5.8838e-03,
#                        1.8550e-01,  2.3146e-01,  1.2876e-01,  4.0703e-01,  1.9364e-01,
#                       -1.1492e-02,  2.4262e-01,  1.4363e-01,  2.3389e-01, -3.4730e-03,
#                        9.8903e-03, -3.0350e-01,  3.7856e-02,  1.9530e-01, -1.1448e-01,
#                        2.0195e-01, -3.9286e-02,  2.1877e-01, -5.3535e-02, -4.9700e-03,
#                        1.9609e-01,  2.4523e-02, -1.6259e-01,  2.7716e-01,  8.2534e-02,
#                        3.0827e-02,  5.1381e-01,  2.9080e-01, -5.2662e-02, -4.8307e-02,
#                        9.9416e-02,  1.5353e-01,  1.5502e-01,  2.4610e-01,  3.8167e-02,
#                        1.1499e-01,  8.5638e-02, -9.4195e-02,  4.0163e-01, -2.8248e-02,
#                       -9.8850e-03,  1.9799e-01,  2.1506e-02, -3.4404e-01,  7.7447e-02,
#                        4.5228e-01, -1.6084e-01,  2.7026e-01,  5.0208e-01, -2.7481e-02,
#                        1.2092e-01, -2.0132e-02,  1.6377e-01, -3.0259e-01,  2.2314e-01,
#                        1.1831e-01,  2.6328e-01, -1.4749e-01,  2.7036e-01,  1.6913e-01,
#                        8.7011e-02,  6.0851e-02,  2.1190e-01,  3.1637e-01,  2.5912e-01,
#                       -9.6966e-03,  1.5300e-01,  1.1871e-01, -2.0507e-01,  2.3820e-01,
#                        1.3533e-01,  4.8526e-01,  2.3789e-01,  4.6820e-01,  9.4878e-02,
#                        3.9203e-01,  4.1590e-02,  2.6736e-02,  7.2134e-02, -1.8213e-01,
#                        1.5196e-01,  1.7484e-02,  5.0898e-02,  2.6800e-01,  2.4570e-01,
#                        2.9309e-01,  1.2544e-01,  2.5765e-01,  3.6328e-01, -2.1809e-02,
#                        2.7822e-01, -8.9615e-02,  2.4350e-01,  2.0452e-01,  3.1978e-01,
#                        1.3638e-01, -1.8719e-01,  1.3047e-01, -1.2245e-02,  8.0052e-02],
#                      device='cuda:0')),
#              ('linear_relu_stack.2.weight',
#               tensor([[-0.0576,  0.0452,  0.0626,  ..., -0.2330, -0.0087,  0.0450],
#                       [ 0.0634,  0.0175, -0.0462,  ...,  0.0085, -0.1365, -0.0595],
#                       [ 0.0322, -0.0264, -0.0819,  ..., -0.0766,  0.0162,  0.0115],
#                       ...,
#                       [-0.1282,  0.0112, -0.2808,  ..., -0.0570,  0.0053, -0.0763],
#                       [-0.0017,  0.0429, -0.2322,  ..., -0.0448,  0.0737,  0.0822],
#                       [-0.2005, -0.0133, -0.2507,  ...,  0.0750,  0.0318, -0.1297]],
#                      device='cuda:0')),
#              ('linear_relu_stack.2.bias',
#               tensor([-0.0457, -0.2098,  0.1699,  0.1936, -0.2313,  0.0294,  0.1376,  0.1220,
#                       -0.0269, -0.3133], device='cuda:0'))])

# %%
torch.save(model.state_dict(), "model.pth")

# %% [markdown]
# ## Загрузка модели

# %%
model = NeuralNetwork().to(device)
model.load_state_dict(torch.load("model.pth"))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ## Распознавание изображений из тестового набора данных

# %%
model.eval()
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=800, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=800, out_features=10, bias=True)
#   )
# )

# %%
x, y = test_data[1][0], test_data[1][1]

# %%
plt.imshow(x[0, :, :], vmin=0, vmax=1.0, cmap=cm.gray)

# %% [markdown]
# Запускаем распознавание

# %%
with torch.no_grad():
    x = x.to(device)
    pred = model(x)

# %% [markdown]
# Результаты распознавания

# %%
pred
# Out:
# tensor([[ -3.8237, -17.8895,   4.3959, -12.0839,  -0.3873, -15.8246,  -1.8190,
#          -14.8083, -15.0565, -14.3466]], device='cuda:0')

# %% [markdown]
# Номер класса

# %%
pred[0].argmax(0)
# Out:
# tensor(2, device='cuda:0')

# %% [markdown]
# Название класса

# %%
classes_names[pred[0].argmax(0)]
# Out:
# 'Свитер'

# %% [markdown]
# Правильный ответ

# %%
y
# Out:
# 2

# %%
classes_names[y]
# Out:
# 'Свитер'
