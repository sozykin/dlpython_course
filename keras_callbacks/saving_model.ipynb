# %% [markdown]
# # Сохранение нейронной сети в процессе обучения
#
# Пример использования [ModelCheckpoint Callback](https://keras.io/api/callbacks/model_checkpoint/).
#
# Чтобы запускать и редактировать код, сохраните копию этого ноутбука себе (Файл -> Создать копию на Диске). Свою копию вы сможете изменять и запускать.
#
# Учебный курс "[Программирование глубоких нейронных сетей на Python](https://openedu.ru/course/urfu/PYDNN/)".
#
# <a target="_blank" href="https://colab.research.google.com/github/sozykin/dlpython_course/blob/master/keras_callbacks/saving_model.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Rescaling, Flatten
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint

# %% [markdown]
# # Загружаем данные Fashion MNIST

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# # Создаем нейронную сеть

# %%
# Создаем последовательную модель
model = Sequential(
    [   
        # Слой, который преобразует матрицу 28х28 в плоский вектор
        Flatten(),
        # Слой нормализации
        Rescaling(1./255),
        # Входной полносвязный слой, 800 нейрона
        # Количество входов не указываем, Keras определяет автоматически
        # после первого запуска
        Dense(800, activation="relu"),
        # Выходной полносвязный слой, 10 нейронов (по количеству классов)
        Dense(10, activation="softmax")
    ]
)

# %% [markdown]
# Компилируем сеть

# %%
model.compile(loss="sparse_categorical_crossentropy", 
              optimizer="adam",
              metrics=["accuracy"])

# %% [markdown]
# ## Создаем Callback для ModelCheckpoint

# %% [markdown]
# Сохраняем сеть на каждой эпохе

# %%
# {epoch:02d} - номер эпохи
# {val_accuracy:.4f} - значение accuracy на проверочном ноборе данных
checkpoint_all = ModelCheckpoint('save/fmnist-dense-{epoch:02d}-{val_accuracy:.4f}.keras')

# %% [markdown]
# Сохраняем только лучший вариант сети

# %%
checkpoint_best = ModelCheckpoint('save/fmnist-dense.keras', 
                             monitor='val_accuracy', 
                             mode='max',
                             save_best_only=True,
                             verbose=1)

# %% [markdown]
# ## Запускаем обучение нейронной сети

# %%
history = model.fit(x_train,
                    y_train, 
                    batch_size=200, 
                    epochs=25, 
                    validation_split=0.2, 
                    verbose=2, 
                    callbacks=[checkpoint_best])
# Out:
# Epoch 1/25
#
# Epoch 1: val_accuracy improved from None to 0.85225, saving model to save/fmnist-dense.keras
# 240/240 - 9s - 39ms/step - accuracy: 0.8147 - loss: 0.5340 - val_accuracy: 0.8522 - val_loss: 0.4203
# Epoch 2/25
#
# Epoch 2: val_accuracy improved from 0.85225 to 0.85925, saving model to save/fmnist-dense.keras
# 240/240 - 5s - 20ms/step - accuracy: 0.8629 - loss: 0.3863 - val_accuracy: 0.8593 - val_loss: 0.3891
# Epoch 3/25
#
# Epoch 3: val_accuracy improved from 0.85925 to 0.87558, saving model to save/fmnist-dense.keras
# 240/240 - 5s - 19ms/step - accuracy: 0.8751 - loss: 0.3432 - val_accuracy: 0.8756 - val_loss: 0.3522
# Epoch 4/25
#
# Epoch 4: val_accuracy improved from 0.87558 to 0.87842, saving model to save/fmnist-dense.keras
# 240/240 - 5s - 19ms/step - accuracy: 0.8857 - loss: 0.3169 - val_accuracy: 0.8784 - val_loss: 0.3417
# Epoch 5/25
#
# Epoch 5: val_accuracy improved from 0.87842 to 0.88125, saving model to save/fmnist-dense.keras
# 240/240 - 12s - 51ms/step - accuracy: 0.8922 - loss: 0.2950 - val_accuracy: 0.8813 - val_loss: 0.3392
# Epoch 6/25
#
# Epoch 6: val_accuracy improved from 0.88125 to 0.88558, saving model to save/fmnist-dense.keras
# 240/240 - 3s - 12ms/step - accuracy: 0.8990 - loss: 0.2777 - val_accuracy: 0.8856 - val_loss: 0.3220
# Epoch 7/25
#
# Epoch 7: val_accuracy improved from 0.88558 to 0.88867, saving model to save/fmnist-dense.keras
# 240/240 - 1s - 5ms/step - accuracy: 0.9029 - loss: 0.2669 - val_accuracy: 0.8887 - val_loss: 0.3134
# Epoch 8/25
#
# Epoch 8: val_accuracy improved from 0.88867 to 0.88875, saving model to save/fmnist-dense.keras
# 240/240 - 1s - 6ms/step - accuracy: 0.9067 - loss: 0.2511 - val_accuracy: 0.8888 - val_loss: 0.3098
# Epoch 9/25
#
# Epoch 9: val_accuracy did not improve from 0.88875
# 240/240 - 1s - 5ms/step - accuracy: 0.9114 - loss: 0.2406 - val_accuracy: 0.8868 - val_loss: 0.3182
# Epoch 10/25
#
# Epoch 10: val_accuracy did not improve from 0.88875
# 240/240 - 3s - 13ms/step - accuracy: 0.9151 - loss: 0.2327 - val_accuracy: 0.8888 - val_loss: 0.3146
# Epoch 11/25
#
# Epoch 11: val_accuracy improved from 0.88875 to 0.89200, saving model to save/fmnist-dense.keras
# 240/240 - 4s - 18ms/step - accuracy: 0.9200 - loss: 0.2191 - val_accuracy: 0.8920 - val_loss: 0.3072
# Epoch 12/25
#
# Epoch 12: val_accuracy did not improve from 0.89200
# 240/240 - 4s - 17ms/step - accuracy: 0.9237 - loss: 0.2102 - val_accuracy: 0.8907 - val_loss: 0.3019
# Epoch 13/25
#
# Epoch 13: val_accuracy did not improve from 0.89200
# 240/240 - 4s - 17ms/step - accuracy: 0.9249 - loss: 0.2029 - val_accuracy: 0.8867 - val_loss: 0.3251
# Epoch 14/25
#
# Epoch 14: val_accuracy did not improve from 0.89200
# 240/240 - 4s - 17ms/step - accuracy: 0.9280 - loss: 0.1951 - val_accuracy: 0.8896 - val_loss: 0.3182
# Epoch 15/25
#
# Epoch 15: val_accuracy improved from 0.89200 to 0.89658, saving model to save/fmnist-dense.keras
# 240/240 - 5s - 21ms/step - accuracy: 0.9318 - loss: 0.1863 - val_accuracy: 0.8966 - val_loss: 0.2919
# Epoch 16/25
#
# Epoch 16: val_accuracy improved from 0.89658 to 0.89692, saving model to save/fmnist-dense.keras
# 240/240 - 4s - 18ms/step - accuracy: 0.9346 - loss: 0.1799 - val_accuracy: 0.8969 - val_loss: 0.2948
# Epoch 17/25
#
# Epoch 17: val_accuracy did not improve from 0.89692
# 240/240 - 4s - 17ms/step - accuracy: 0.9364 - loss: 0.1720 - val_accuracy: 0.8926 - val_loss: 0.3204
# Epoch 18/25
#
# Epoch 18: val_accuracy did not improve from 0.89692
# 240/240 - 5s - 22ms/step - accuracy: 0.9370 - loss: 0.1711 - val_accuracy: 0.8940 - val_loss: 0.3098
# Epoch 19/25
#
# Epoch 19: val_accuracy did not improve from 0.89692
# 240/240 - 4s - 17ms/step - accuracy: 0.9405 - loss: 0.1637 - val_accuracy: 0.8942 - val_loss: 0.3184
# Epoch 20/25
#
# Epoch 20: val_accuracy improved from 0.89692 to 0.89717, saving model to save/fmnist-dense.keras
# 240/240 - 4s - 18ms/step - accuracy: 0.9422 - loss: 0.1584 - val_accuracy: 0.8972 - val_loss: 0.3080
# Epoch 21/25
#
# Epoch 21: val_accuracy improved from 0.89717 to 0.89975, saving model to save/fmnist-dense.keras
# 240/240 - 4s - 18ms/step - accuracy: 0.9470 - loss: 0.1489 - val_accuracy: 0.8997 - val_loss: 0.3020
# Epoch 22/25
#
# Epoch 22: val_accuracy did not improve from 0.89975
# 240/240 - 5s - 22ms/step - accuracy: 0.9455 - loss: 0.1477 - val_accuracy: 0.8952 - val_loss: 0.3158
# Epoch 23/25
#
# Epoch 23: val_accuracy did not improve from 0.89975
# 240/240 - 4s - 17ms/step - accuracy: 0.9482 - loss: 0.1432 - val_accuracy: 0.8943 - val_loss: 0.3209
# Epoch 24/25
#
# Epoch 24: val_accuracy did not improve from 0.89975
# 240/240 - 4s - 18ms/step - accuracy: 0.9501 - loss: 0.1378 - val_accuracy: 0.8958 - val_loss: 0.3322
# Epoch 25/25
#
# Epoch 25: val_accuracy did not improve from 0.89975
# 240/240 - 4s - 18ms/step - accuracy: 0.9519 - loss: 0.1331 - val_accuracy: 0.8947 - val_loss: 0.3309

# %% [markdown]
# ## Загружаем лучшую модель

# %%
best_model = load_model('save/fmnist-dense.keras')

# %% [markdown]
# ## Проверяем лучшую модель на тестовых данных

# %%
test_loss, test_accuracy = best_model.evaluate(x_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8911 - loss: 0.3348

# %%
test_accuracy
# Out:
# 0.8910999894142151
